# %%
import torch
import numpy as np
import matplotlib.pyplot as plt

from util.util import Timing, get_expon_lr_func, get_linear_expon_lr_func, generate_dirs_equirect, viridis_cmap, get_linear_lr_func

# %%
start = 2e-2
final = 1e-4
delay_steps = 0
delay_mult = 1e-2
decay_steps = 75000


func = get_expon_lr_func(start, final, delay_steps,
                                  delay_mult, decay_steps)

xs = np.linspace(0, decay_steps, 10000)
ys = [func(x) for x in xs]

plt.plot(xs,ys)

# %%
start = 10
final = 1e-2
delay_steps = 50000
delay_mult = 1e-2
decay_steps = 100000


func = get_expon_lr_func(start, final, delay_steps,
                                  delay_mult, decay_steps)

xs = np.linspace(0, decay_steps, 10000)
ys = [func(x) for x in xs]

plt.plot(xs,ys)



start = 1
final = 1e-2
delay_steps = 50000
delay_mult = 1e-4
decay_steps = 100000


func = get_linear_expon_lr_func(start, final, delay_steps,
                                  delay_mult, decay_steps)

xs = np.linspace(0, decay_steps, 10000)
ys = [func(x) for x in xs]

plt.plot(xs,ys)

# %%
start = 1e-3
final = 1e-4
delay_steps = 50000
delay_mult = 1e-2
decay_steps = 100000


func = get_expon_lr_func(start, final, delay_steps,
                                  delay_mult, decay_steps)

xs = np.linspace(0, decay_steps, 10000)
ys = [func(x) for x in xs]

plt.plot(xs,ys)
