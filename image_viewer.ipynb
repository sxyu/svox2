# %%
# %matplotlib inline
import numpy as np
import k3d
from k3d.colormaps import matplotlib_color_maps
import pathlib
import matplotlib.pyplot as plt
import imageio
import svox2
import torch
import tqdm
# Out:
# /home/tw554/plenoxels/svox2/utils.py:42: UserWarning: CUDA extension svox2.csrc could not be loaded! Operations will be slow.
# Please do not import svox in the svox2 source directory.
#   warn("CUDA extension svox2.csrc could not be loaded! " +

# %%
path = '/home/tw554/plenoxels/data/nerf_synthetic/ship_re/train/r_0.png'
img = imageio.imread(path) / 255

img = img * img[:,:,3:] # + (1. - img[:,:,3:])

imageio.imsave('imgs/debug.png', img[:,:,:3])
# Out:
# /tmp/ipykernel_3579116/4025344103.py:2: DeprecationWarning: Starting with ImageIO v3 the behavior of this function will switch to that of iio.v3.imread. To keep the current behavior (and make this warning dissapear) use `import imageio.v2 as imageio` or call `imageio.v2.imread` directly.
#   img = imageio.imread(path) / 255
# Lossy conversion from float64 to uint8. Range [0, 1]. Convert image to uint8 prior to saving to suppress this warning.

# %%
# %matplotlib notebook

path = '/home/tw554/plenoxels/imgs/individualImage.png'
img = imageio.imread(path)

plt.rcParams['figure.figsize'] = [10,10]
plt.imshow(img)
plt.show()
# Out:
# /tmp/ipykernel_2237039/1268264342.py:4: DeprecationWarning: Starting with ImageIO v3 the behavior of this function will switch to that of iio.v3.imread. To keep the current behavior (and make this warning dissapear) use `import imageio.v2 as imageio` or call `imageio.v2.imread` directly.
#   img = imageio.imread(path)
# <img src="data:image/png;base64,..." width="1000.0000264909539">

# %%
# %matplotlib notebook

path = '/home/tw554/plenoxels/imgs/individualImage (1).png'
img = imageio.imread(path)

plt.rcParams['figure.figsize'] = [10,10]
plt.imshow(img)
plt.show()
# Out:
# /tmp/ipykernel_2237039/1442893190.py:4: DeprecationWarning: Starting with ImageIO v3 the behavior of this function will switch to that of iio.v3.imread. To keep the current behavior (and make this warning dissapear) use `import imageio.v2 as imageio` or call `imageio.v2.imread` directly.
#   img = imageio.imread(path)
# <img src="data:image/png;base64,..." width="1000.0000264909539">

# %%
11
# Out:
# Array([[0.50980392, 0.50980392, 0.50980392, 0.50980392],
#        [0.50980392, 0.50980392, 0.50980392, 0.50980392],
#        [0.50980392, 0.50980392, 0.50980392, 0.50980392],
#        ...,
#        [0.41176471, 0.41176471, 0.41176471, 0.41176471],
#        [0.41176471, 0.41176471, 0.41176471, 0.41176471],
#        [0.41176471, 0.41176471, 0.41176471, 0.41176471]])

# %%
y, x = [648, 870]
img[x, y]
# Out:
# Array([236, 228, 227], dtype=uint8)

# %%
# y, x = [490, 237]
# y, x = [501, 94]
img = imageio.imread(path)
img[x, y] = [255, 0, 0]

# %matplotlib notebook
plt.rcParams['figure.figsize'] = [10,10]
plt.imshow(img)
plt.show()
# Out:
# /tmp/ipykernel_1175675/2196041328.py:3: DeprecationWarning: Starting with ImageIO v3 the behavior of this function will switch to that of iio.v3.imread. To keep the current behavior (and make this warning dissapear) use `import imageio.v2 as imageio` or call `imageio.v2.imread` directly.
#   img = imageio.imread(path)
# <img src="data:image/png;base64,..." width="1000">

# %%
# %matplotlib notebook
gt_path = '/home/tw554/plenoxels/data/dtu/dtu_scan63/image/000016.png'
mask_path = '/home/tw554/plenoxels/data/dtu/dtu_scan63/mask/016.png'

gt_img = imageio.imread(gt_path)
mask  = imageio.imread(mask_path)

gt_img[mask == 0] = 255

diff = np.average(np.abs(gt_img - img),axis=-1)
# diff = np.abs(gt_img - img)

plt.rcParams['figure.figsize'] = [10,10]
plt.imshow(diff)
plt.show()
# Out:
# /tmp/ipykernel_182974/3892743094.py:5: DeprecationWarning: Starting with ImageIO v3 the behavior of this function will switch to that of iio.v3.imread. To keep the current behavior (and make this warning dissapear) use `import imageio.v2 as imageio` or call `imageio.v2.imread` directly.
#   gt_img = imageio.imread(gt_path)
# /tmp/ipykernel_182974/3892743094.py:6: DeprecationWarning: Starting with ImageIO v3 the behavior of this function will switch to that of iio.v3.imread. To keep the current behavior (and make this warning dissapear) use `import imageio.v2 as imageio` or call `imageio.v2.imread` directly.
#   mask  = imageio.imread(mask_path)
# <img src="data:image/png;base64,..." width="1500.0000397364308">

# %%
# %matplotlib notebook
plt.rcParams['figure.figsize'] = [10,10]
plt.imshow(gt_img)
plt.show()
# Out:
# <img src="data:image/png;base64,..." width="1000.0000264909539">

# %%
# %matplotlib notebook
plt.rcParams['figure.figsize'] = [10,10]
plt.imshow(img)
plt.show()
# Out:
# <img src="data:image/png;base64,..." width="1000.0000264909539">
